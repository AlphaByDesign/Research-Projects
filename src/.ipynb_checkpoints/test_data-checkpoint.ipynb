# %%
from typing import List
# !pip install pyarrow

from src import visualization
# Out:
# Requirement already satisfied: pyarrow in c:\users\amin\pycharmprojects\pythonproject\.venv\lib\site-packages (22.0.0)

# %%
from importlib import reload
import src.features as features
reload(features)
from src.features import get_historical_data

# %%
data_df = get_historical_data(symbol= "BTCUSDT")
data_df.head()
# Out:
# shape: (5, 6)
# ┌─────────────────────┬──────────┬──────────┬──────────┬──────────┬──────────────┐
# │ date                ┆ open     ┆ high     ┆ low      ┆ close    ┆ volume       │
# │ ---                 ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---          │
# │ datetime[ms]        ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64          │
# ╞═════════════════════╪══════════╪══════════╪══════════╪══════════╪══════════════╡
# │ 2020-11-11 00:00:00 ┆ 15297.21 ┆ 15499.58 ┆ 15272.68 ┆ 15401.9  ┆ 11252.097142 │
# │ 2020-11-11 04:00:00 ┆ 15401.9  ┆ 15441.37 ┆ 15322.02 ┆ 15400.51 ┆ 5830.865996  │
# │ 2020-11-11 08:00:00 ┆ 15400.5  ┆ 15680.0  ┆ 15363.37 ┆ 15574.48 ┆ 13706.745887 │
# │ 2020-11-11 12:00:00 ┆ 15574.48 ┆ 15718.91 ┆ 15477.0  ┆ 15667.27 ┆ 13545.826971 │
# │ 2020-11-11 16:00:00 ┆ 15667.5  ┆ 15965.0  ┆ 15639.21 ┆ 15807.58 ┆ 22805.0493   │
# └─────────────────────┴──────────┴──────────┴──────────┴──────────┴──────────────┘

# %%
from src.features import create_time_series_transform

# %%
from importlib import reload
import src.features as features
reload(features)
# Out:
# <module 'src.features' from 'C:\\Users\\Amin\\PycharmProjects\\PythonProject\\src\\features.py'>

# %%
from src.features import create_time_series_transform

# %%
df = create_time_series_transform(data_df,"close",forecast_horizon=1)

# %%
df
# Out:
# shape: (11_018, 8)
# ┌─────────────┬──────────┬──────────┬──────────┬──────────┬─────────────┬─────────────┬────────────┐
# │ date        ┆ open     ┆ high     ┆ low      ┆ close    ┆ volume      ┆ close_log_r ┆ log_volume │
# │ ---         ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---         ┆ eturn       ┆ ---        │
# │ datetime[ms ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64         ┆ ---         ┆ f64        │
# │ ]           ┆          ┆          ┆          ┆          ┆             ┆ f64         ┆            │
# ╞═════════════╪══════════╪══════════╪══════════╪══════════╪═════════════╪═════════════╪════════════╡
# │ 2020-11-11  ┆ 15297.21 ┆ 15499.58 ┆ 15272.68 ┆ 15401.9  ┆ 11252.09714 ┆ null        ┆ null       │
# │ 00:00:00    ┆          ┆          ┆          ┆          ┆ 2           ┆             ┆            │
# │ 2020-11-11  ┆ 15401.9  ┆ 15441.37 ┆ 15322.02 ┆ 15400.51 ┆ 5830.865996 ┆ -0.00009    ┆ -0.657389  │
# │ 04:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2020-11-11  ┆ 15400.5  ┆ 15680.0  ┆ 15363.37 ┆ 15574.48 ┆ 13706.74588 ┆ 0.011233    ┆ 0.854723   │
# │ 08:00:00    ┆          ┆          ┆          ┆          ┆ 7           ┆             ┆            │
# │ 2020-11-11  ┆ 15574.48 ┆ 15718.91 ┆ 15477.0  ┆ 15667.27 ┆ 13545.82697 ┆ 0.00594     ┆ -0.01181   │
# │ 12:00:00    ┆          ┆          ┆          ┆          ┆ 1           ┆             ┆            │
# │ 2020-11-11  ┆ 15667.5  ┆ 15965.0  ┆ 15639.21 ┆ 15807.58 ┆ 22805.0493  ┆ 0.008916    ┆ 0.520903   │
# │ 16:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ …           ┆ …        ┆ …        ┆ …        ┆ …        ┆ …           ┆ …           ┆ …          │
# │ 2025-11-20  ┆ 91934.01 ┆ 92541.92 ┆ 89835.34 ┆ 89869.88 ┆ 6162.85424  ┆ -0.022708   ┆ 0.655128   │
# │ 12:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-20  ┆ 89869.88 ┆ 89911.73 ┆ 86100.0  ┆ 86921.28 ┆ 17595.68288 ┆ -0.03336    ┆ 1.049114   │
# │ 16:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-20  ┆ 86921.27 ┆ 88250.0  ┆ 86325.23 ┆ 86637.23 ┆ 5052.86651  ┆ -0.003273   ┆ -1.247698  │
# │ 20:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-21  ┆ 86637.22 ┆ 87498.94 ┆ 85360.0  ┆ 85821.34 ┆ 6428.51913  ┆ -0.009462   ┆ 0.240788   │
# │ 00:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-21  ┆ 85821.35 ┆ 85923.07 ┆ 85417.98 ┆ 85476.67 ┆ 614.00255   ┆ -0.004024   ┆ -2.3485    │
# │ 04:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# └─────────────┴──────────┴──────────┴──────────┴──────────┴─────────────┴─────────────┴────────────┘

# %%
new=features.create_time_series_transform(df)

# %%
new
# Out:
# shape: (11_018, 8)
# ┌─────────────┬──────────┬──────────┬──────────┬──────────┬─────────────┬─────────────┬────────────┐
# │ date        ┆ open     ┆ high     ┆ low      ┆ close    ┆ volume      ┆ close_log_r ┆ log_volume │
# │ ---         ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---         ┆ eturn       ┆ ---        │
# │ datetime[ms ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64         ┆ ---         ┆ f64        │
# │ ]           ┆          ┆          ┆          ┆          ┆             ┆ f64         ┆            │
# ╞═════════════╪══════════╪══════════╪══════════╪══════════╪═════════════╪═════════════╪════════════╡
# │ 2020-11-11  ┆ 15297.21 ┆ 15499.58 ┆ 15272.68 ┆ 15401.9  ┆ 11252.09714 ┆ null        ┆ null       │
# │ 00:00:00    ┆          ┆          ┆          ┆          ┆ 2           ┆             ┆            │
# │ 2020-11-11  ┆ 15401.9  ┆ 15441.37 ┆ 15322.02 ┆ 15400.51 ┆ 5830.865996 ┆ -0.00009    ┆ -0.657389  │
# │ 04:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2020-11-11  ┆ 15400.5  ┆ 15680.0  ┆ 15363.37 ┆ 15574.48 ┆ 13706.74588 ┆ 0.011233    ┆ 0.854723   │
# │ 08:00:00    ┆          ┆          ┆          ┆          ┆ 7           ┆             ┆            │
# │ 2020-11-11  ┆ 15574.48 ┆ 15718.91 ┆ 15477.0  ┆ 15667.27 ┆ 13545.82697 ┆ 0.00594     ┆ -0.01181   │
# │ 12:00:00    ┆          ┆          ┆          ┆          ┆ 1           ┆             ┆            │
# │ 2020-11-11  ┆ 15667.5  ┆ 15965.0  ┆ 15639.21 ┆ 15807.58 ┆ 22805.0493  ┆ 0.008916    ┆ 0.520903   │
# │ 16:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ …           ┆ …        ┆ …        ┆ …        ┆ …        ┆ …           ┆ …           ┆ …          │
# │ 2025-11-20  ┆ 91934.01 ┆ 92541.92 ┆ 89835.34 ┆ 89869.88 ┆ 6162.85424  ┆ -0.022708   ┆ 0.655128   │
# │ 12:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-20  ┆ 89869.88 ┆ 89911.73 ┆ 86100.0  ┆ 86921.28 ┆ 17595.68288 ┆ -0.03336    ┆ 1.049114   │
# │ 16:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-20  ┆ 86921.27 ┆ 88250.0  ┆ 86325.23 ┆ 86637.23 ┆ 5052.86651  ┆ -0.003273   ┆ -1.247698  │
# │ 20:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-21  ┆ 86637.22 ┆ 87498.94 ┆ 85360.0  ┆ 85821.34 ┆ 6428.51913  ┆ -0.009462   ┆ 0.240788   │
# │ 00:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# │ 2025-11-21  ┆ 85821.35 ┆ 85923.07 ┆ 85417.98 ┆ 85476.67 ┆ 614.00255   ┆ -0.004024   ┆ -2.3485    │
# │ 04:00:00    ┆          ┆          ┆          ┆          ┆             ┆             ┆            │
# └─────────────┴──────────┴──────────┴──────────┴──────────┴─────────────┴─────────────┴────────────┘

# %%
from importlib import reload
import src.features as features
reload(features)
# Out:
# <module 'src.features' from 'C:\\Users\\Amin\\PycharmProjects\\PythonProject\\src\\features.py'>

# %%
from src.features import create_lag_feature

# %%
df = create_lag_feature(new,["close_log_return"],max_lags=4,forecast_horizon=1)
df
# Out:
# shape: (11_013, 12)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ date       ┆ open     ┆ high     ┆ low      ┆ … ┆ close_log_ ┆ close_log ┆ close_log ┆ close_log │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆   ┆ return_lag ┆ _return_l ┆ _return_l ┆ _return_l │
# │ datetime[m ┆ f64      ┆ f64      ┆ f64      ┆   ┆ 1          ┆ ag2       ┆ ag3       ┆ ag4       │
# │ s]         ┆          ┆          ┆          ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆          ┆   ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2020-11-11 ┆ 15807.58 ┆ 15886.0  ┆ 15576.04 ┆ … ┆ 0.008916   ┆ 0.00594   ┆ 0.011233  ┆ -0.00009  │
# │ 20:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2020-11-12 ┆ 15684.25 ┆ 15711.77 ┆ 15440.64 ┆ … ┆ -0.007833  ┆ 0.008916  ┆ 0.00594   ┆ 0.011233  │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2020-11-12 ┆ 15628.14 ┆ 15945.0  ┆ 15591.54 ┆ … ┆ -0.003583  ┆ -0.007833 ┆ 0.008916  ┆ 0.00594   │
# │ 04:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2020-11-12 ┆ 15862.75 ┆ 16160.89 ┆ 15600.0  ┆ … ┆ 0.0149     ┆ -0.003583 ┆ -0.007833 ┆ 0.008916  │
# │ 08:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2020-11-12 ┆ 15762.55 ┆ 16144.5  ┆ 15747.14 ┆ … ┆ -0.006337  ┆ 0.0149    ┆ -0.003583 ┆ -0.007833 │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …        ┆ …        ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025-11-20 ┆ 91934.01 ┆ 92541.92 ┆ 89835.34 ┆ … ┆ -0.004192  ┆ -0.0013   ┆ 0.009624  ┆ 0.029601  │
# │ 12:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-11-20 ┆ 89869.88 ┆ 89911.73 ┆ 86100.0  ┆ … ┆ -0.022708  ┆ -0.004192 ┆ -0.0013   ┆ 0.009624  │
# │ 16:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-11-20 ┆ 86921.27 ┆ 88250.0  ┆ 86325.23 ┆ … ┆ -0.03336   ┆ -0.022708 ┆ -0.004192 ┆ -0.0013   │
# │ 20:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-11-21 ┆ 86637.22 ┆ 87498.94 ┆ 85360.0  ┆ … ┆ -0.003273  ┆ -0.03336  ┆ -0.022708 ┆ -0.004192 │
# │ 00:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# │ 2025-11-21 ┆ 85821.35 ┆ 85923.07 ┆ 85417.98 ┆ … ┆ -0.009462  ┆ -0.003273 ┆ -0.03336  ┆ -0.022708 │
# │ 04:00:00   ┆          ┆          ┆          ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴──────────┴──────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
import seaborn as sns

# %%
import src.visualization
from importlib import reload

reload(src.visualization)


from src.visualization import plot_feature_distribution

# %%
plot_feature_distribution(new,[["close_log_return","close_log_return_lag1","close_log_return_lag2","close_log_return_lag3"]])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plot_feature_distribution(new,[["close_log_return","close_log_return_lag1","close_log_return_lag2","close_log_return_lag3"]])
#
# File ~\PycharmProjects\PythonProject\src\visualization.py:14, in plot_feature_distribution(df, features)
#      10 def plot_feature_distribution(df: pl.DataFrame, features: List[str])-> None:
#      11
#      12 # Transform the Polars df into Pandas for use of Seaborn
# ---> 14     pd_df = df.select(features).to_pandas()
#      16 # Create the pair plot
#      18     sns.pairplot(pd_df,diag_kind="kde")
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\polars\dataframe\frame.py:2562, in DataFrame.to_pandas(self, use_pyarrow_extension_array, **kwargs)
#    2557 if Object in self.dtypes:
#    2558     return self._to_pandas_with_object_columns(
#    2559         use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2560     )
# -> 2562 return self._to_pandas_without_object_columns(
#    2563     self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2564 )
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\polars\dataframe\frame.py:2614, in DataFrame._to_pandas_without_object_columns(self, df, use_pyarrow_extension_array, **kwargs)
#    2611     return pd.DataFrame()
#    2613 record_batches = df._df.to_pandas()
# -> 2614 tbl = pa.Table.from_batches(record_batches)
#    2615 if use_pyarrow_extension_array:
#    2616     return tbl.to_pandas(
#    2617         self_destruct=True,
#    2618         split_blocks=True,
#    2619         types_mapper=lambda pa_dtype: pd.ArrowDtype(pa_dtype),
#    2620         **kwargs,
#    2621     )
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\polars\_dependencies.py:102, in _LazyModule.__getattr__(self, name)
#     100 pfx = self._mod_pfx.get(self._module_name, "")
#     101 msg = f"{pfx}{name} requires {self._module_name!r} module to be installed"
# --> 102 raise ModuleNotFoundError(msg) from None
#
# ModuleNotFoundError: pa.Table requires 'pyarrow' module to be installed
